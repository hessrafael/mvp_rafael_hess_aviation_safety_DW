# %%
# %run
./ingest_bronze_data
# Out:
# '\nIniciando etapa ingest_bronze_data\n'
# '\niniciando import de accidents_data\n'
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
